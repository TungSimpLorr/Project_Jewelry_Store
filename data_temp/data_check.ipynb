# %%
import pandas as pd
import numpy as np

df = pd.read_excel('./data_temp/san_pham.xlsx')

df.head(10)
# Out:
#    id_san_pham ma_san_pham                ten_san_pham            price  \
# 0          NaN     VCJS001  VÒNG CỔ ALEXANDRA DIAMOND           2000000
# 1          NaN     VCJS002  VÒNG CỔ DARKQUEEN DIAMOND           5000000
# 2          NaN     VCJS003     VÒNG CỔ LONELY ROCKSTAR          1000000
# 3          NaN     VCJS004          VÒNG CỔ GOLD LADY           2500000
# 4          NaN     RRJS101        NHẨN LIGHTSTAR RING           1009000
# 5          NaN     VTJS111            VÒNG TAY ĐÍNH ĐÁ   1.399.000,00 đ
# 6          NaN     RRJS102                     NHẪN CZ     999.000,00 đ
# 7          NaN     VCJS005           VÒNG CỔ SWAROVSKI   1.000.000,00 đ
# 8          NaN     KTJS201             HOA TAI VÀNG NỮ  10.000.000,00 đ
# 9          NaN     RRJS103                    NHẪN ĐÔI  49.000.000,00 đ
#
#                                                mo_ta id_thuong_hieu  \
# 0  Với viên kim cương lấp lánh được cắt gọt tinh ...      Aura Gems
# ...
